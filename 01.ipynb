# %%
import pandas_datareader as pdr
import pandas as pd
import datetime 
import matplotlib.pyplot as plt

aapl = pdr.get_data_yahoo('AAPL', 
                          start=datetime.datetime(2006, 10, 1), 
                          end=datetime.datetime(2012, 1, 1))

# %%
#{}.format

# %%
aapl['Volume'].mean()
# Out:
# 188289640.74074075

# %%
aapl[['Adj Close', 'Close']].plot()
plt.show()
